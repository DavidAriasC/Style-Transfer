# %%
iteration = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950]

# %%
# without instnace normalization
total_loss = [2.3308e+08, 2.1105e+07, 1.0979e+07, 6.5913e+06, 4.5712e+06, 3.4669e+06, 2.8065e+06, 2.3755e+06, 2.0734e+06, 1.8542e+06, 1.6885e+06, 1.5616e+06, 1.4626e+06, 1.3836e+06, 1.3194e+06, 1.2660e+06, 1.2207e+06, 1.1817e+06, 1.1482e+06, 1.1189e+06]
style_loss = [2.3308e+08, 1.8413e+07, 8.6472e+06, 4.5779e+06, 2.8408e+06, 1.9783e+06, 1.4973e+06, 1.2088e+06, 1.0193e+06, 8.8228e+05, 7.8944e+05, 7.1931e+05, 6.6589e+05, 6.2517e+05, 5.9434e+05, 5.6894e+05, 5.4854e+05, 5.3022e+05, 5.1496e+05, 5.0196e+05]
content_loss = [0.0000e+00, 2.6922e+06, 2.3320e+06, 2.0134e+06, 1.7305e+06, 1.4887e+06, 1.3092e+06, 1.1667e+06, 1.0541e+06, 9.7193e+05, 8.9908e+05, 8.4230e+05, 7.9672e+05, 7.5842e+05, 7.2509e+05, 6.9706e+05, 6.7214e+05, 6.5149e+05, 6.3321e+05, 6.1694e+05]

# %%
# With instance normalization
total_loss_in = [2.3308e+08, 2.1105e+07, 1.1069e+07, 6.6069e+06, 4.5769e+06, 3.4843e+06, 2.8144e+06, 2.3799e+06, 2.0780e+06, 1.8581e+06, 1.6930e+06, 1.5668e+06, 1.4693e+06, 1.3898e+06, 1.3252e+06, 1.2714e+06, 1.2268e+06, 1.1884e+06, 1.1552e+06, 1.1263e+06]
style_loss_in = [2.3308e+08, 1.8413e+07, 8.7286e+06, 4.5908e+06, 2.8446e+06, 1.9900e+06, 1.5026e+06, 1.2108e+06, 1.0167e+06, 8.8528e+05, 7.9095e+05, 7.2147e+05, 6.6896e+05, 6.2801e+05, 5.9575e+05, 5.6960e+05, 5.4808e+05, 5.3007e+05, 5.1466e+05, 5.0082e+05]
content_loss_in = [0.0000e+00, 2.6922e+06, 2.3407e+06, 2.0161e+06, 1.7323e+06, 1.4943e+06, 1.3118e+06, 1.1691e+06, 1.0613e+06, 9.7281e+05, 9.0208e+05, 8.4538e+05, 8.0031e+05, 7.6174e+05, 7.2943e+05, 7.0182e+05, 6.7871e+05, 6.5830e+05, 6.4054e+05, 6.2550e+05]

# %%
import matplotlib.pyplot as plt

plt.plot(iteration[15:], total_loss[15:], color='blue', label='Total Loss')
plt.plot(iteration[15:], style_loss[15:], color='red', label='Style Loss')
plt.plot(iteration[15:], content_loss[15:], color='green', label='Content Loss')
plt.plot(iteration[15:], total_loss_in[15:], 'o', color='blue', label='Total Loss with IN')
plt.plot(iteration[15:], style_loss_in[15:], 'o', color='red', label='Style Loss with IN')
plt.plot(iteration[15:], content_loss_in[15:], 'o', color='green', label='Content Loss with IN')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# # Comparación content weight (style weight = 1e-2)

# %%
iteration = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950]

total_loss_1e3 = [71047000.0, 4729500.0, 2330100.0, 1439300.0, 1010500.0, 765650.0, 617570.0, 520380.0, 451210.0, 402580.0, 366600.0, 339240.0, 318150.0, 301460.0, 288090.0, 277180.0, 268230.0, 260740.0, 254350.0, 248880.0]
style_loss_1e3 = [71047000.0, 3311800.0, 1260700.0, 625270.0, 381230.0, 263580.0, 200510.0, 163780.0, 140670.0, 124810.0, 113360.0, 105200.0, 98447.0, 93415.0, 89174.0, 85790.0, 82988.0, 80521.0, 78576.0, 77007.0]
content_loss_1e3 = [0.0, 1417700.0, 1069500.0, 814030.0, 629320.0, 502080.0, 417070.0, 356600.0, 310540.0, 277770.0, 253240.0, 234040.0, 219700.0, 208040.0, 198920.0, 191390.0, 185250.0, 180210.0, 175780.0, 171870.0]

# %%
total_loss_1e4 = [7.1047e+07, 8.3738e+06, 4.5838e+06, 3.0578e+06, 2.3200e+06, 1.8888e+06, 1.6018e+06, 1.4077e+06, 1.2723e+06, 1.1740e+06, 1.0998e+06, 1.0432e+06, 1.0000e+06, 9.6508e+05, 9.3674e+05, 9.1317e+05, 8.9400e+05, 8.7798e+05, 8.6439e+05, 8.5272e+05]
style_loss_1e4 = [7.1047e+07, 4.3372e+06, 1.9377e+06, 1.1311e+06, 7.8557e+05, 6.1067e+05, 5.0381e+05, 4.3639e+05, 3.9468e+05, 3.6230e+05, 3.3793e+05, 3.2111e+05, 3.0898e+05, 2.9896e+05, 2.9076e+05, 2.8383e+05, 2.7838e+05, 2.7390e+05, 2.6988e+05, 2.6651e+05]
content_loss_1e4 = [0.0000e+00, 4.0365e+06, 2.6461e+06, 1.9267e+06, 1.5344e+06, 1.2781e+06, 1.0980e+06, 9.7127e+05, 8.7760e+05, 8.1167e+05, 7.6187e+05, 7.2207e+05, 6.9107e+05, 6.6612e+05, 6.4598e+05, 6.2934e+05, 6.1562e+05, 6.0408e+05, 5.9450e+05, 5.8621e+05]

# %%
import matplotlib.pyplot as plt

plt.plot(iteration[3:], total_loss_1e3[3:], color='blue', label='Total Loss (Content weight = 1e3)')
plt.plot(iteration[3:], style_loss_1e3[3:], color='red', label='Style Loss (Content weight = 1e3)')
plt.plot(iteration[3:], content_loss_1e3[3:], color='green', label='Content Loss (Content weight = 1e3)')
plt.plot(iteration[3:], total_loss_1e4[3:], 'o', color='blue', label='Total Loss (Content weight = 1e4)')
plt.plot(iteration[3:], style_loss_1e4[3:], 'o', color='red', label='Style Loss (Content weight = 1e4)')
plt.plot(iteration[3:], content_loss_1e4[3:], 'o', color='green', label='Content Loss (Content weight = 1e4)')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# # Comparación style weight (content weight = 1e3)

# %%
# Style weight = 0.01

iteration = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950]
total_loss_orig = [7.1047e+07, 4.7295e+06, 2.3301e+06, 1.4393e+06, 1.0105e+06, 7.6565e+05, 6.1757e+05, 5.2038e+05, 4.5121e+05, 4.0258e+05, 3.6660e+05, 3.3924e+05, 3.1815e+05, 3.0146e+05, 2.8809e+05, 2.7723e+05, 2.6825e+05, 2.6076e+05, 2.5451e+05, 2.4933e+05]
style_loss_orig = [7.1047e+07, 3.3118e+06, 1.2607e+06, 6.2527e+05, 3.8123e+05, 2.6358e+05, 2.0051e+05, 1.6378e+05, 1.4067e+05, 1.2481e+05, 1.1336e+05, 1.0520e+05, 9.8447e+04, 9.3415e+04, 8.9174e+04, 8.5853e+04, 8.3348e+04, 8.1352e+04, 7.9751e+04, 7.8469e+04]
content_loss_orig = [0.0000e+00, 1.4177e+06, 1.0695e+06, 8.1403e+05, 6.2932e+05, 5.0208e+05, 4.1707e+05, 3.5660e+05, 3.1054e+05, 2.7777e+05, 2.5324e+05, 2.3404e+05, 2.1970e+05, 2.0804e+05, 1.9892e+05, 1.9220e+05, 1.8701e+05, 1.8284e+05, 1.7954e+05, 1.7696e+05]

# %%
# Style weight = 0.1

total_loss_list = [710470000.0, 34982000.0, 13702000.0, 7293700.0, 4705000.0, 3377200.0, 2594000.0, 2097100.0, 1764100.0, 1535400.0, 1370400.0, 1245700.0, 1150400.0, 1076300.0, 1016400.0, 966670.0, 925330.0, 890510.0, 860170.0, 833850.0]
style_loss_list = [710470000.0, 32772000.0, 11537000.0, 5266700.0, 2897500.0, 1796800.0, 1226400.0, 905730.0, 718930.0, 599270.0, 519630.0, 465680.0, 425240.0, 394390.0, 371180.0, 352490.0, 337290.0, 324100.0, 312770.0, 303360.0]
content_loss_list = [0.0, 2210300.0, 2164900.0, 2027000.0, 1807500.0, 1580400.0, 1367700.0, 1191400.0, 1045200.0, 936100.0, 850800.0, 780010.0, 725150.0, 681910.0, 645220.0, 614180.0, 588040.0, 566410.0, 547400.0, 530490.0]

# %%
import matplotlib.pyplot as plt

plt.plot(iteration[3:], total_loss_orig[3:], color='blue', label='Total Loss (Style weight = 0.01)')
plt.plot(iteration[3:], style_loss_orig[3:], color='red', label='Style Loss (Style weight = 0.01)')
plt.plot(iteration[3:], content_loss_orig[3:], color='green', label='Content Loss (Style weight = 0.01)')
plt.plot(iteration[3:], total_loss_list[3:], 'o', color='blue', label='Total Loss (Style weight = 0.1)')
plt.plot(iteration[3:], style_loss_list[3:], 'o', color='red', label='Style Loss (Style weight = 0.1)')
plt.plot(iteration[3:], content_loss_list[3:], 'o', color='green', label='Content Loss (Style weight = 0.1)')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()
